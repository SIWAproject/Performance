# %%
from importlib import reload  
from boto3 import client, resource
import awswrangler as wr

# %%
import swine
import s3utils
reload(swine)
reload(s3utils)
from s3utils import *

# %%
import sys
sys.path.insert(1, "/Users/dvarelat/Documents/SIWA/dataExploration")
import utils
reload(utils)
# Out:
# <module 'utils' from '/Users/dvarelat/Documents/SIWA/dataExploration/utils.py'>

# %% [markdown]
# ## CHECK ANIMAL ID

# %%
s3_client = client(
            "s3",
            aws_access_key_id="AKIATNNTOXHYYITGFJP5",
            aws_secret_access_key="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",
        )
animal_file = getAnimalFile(s3_client)

# %%
animal_file
# Out:
#      AnimalID KitID  TreatmentNumber  \
# 0     H001_01  H001              1.0
# 1     H001_02  H001              1.0
# 2     H001_03  H001              1.0
# 3     H001_04  H001              1.0
# 4     H001_05  H001              1.0
# ...       ...   ...              ...
# 1673  0114_02  0114             10.0
# 1674  0114_03  0114             10.0
# 1675  0114_04  0114             10.0
# 1676  0114_05  0114             10.0
# 1677  0114_06  0114             10.0
#
#                                               Treatment   Age AnimalNumber  \
# 0     Control Negativo basal sin antibióticos y sin ...  14.0            1
# 1     Control Negativo basal sin antibióticos y sin ...  14.0            2
# 2     Control Negativo basal sin antibióticos y sin ...  14.0            3
# 3     Control Negativo basal sin antibióticos y sin ...  14.0            4
# 4     Control Negativo basal sin antibióticos y sin ...  14.0            5
# ...

# %%
animal_file[animal_file.Project == "E321"]
# Out:
#      AnimalID KitID  TreatmentNumber         Treatment   Age AnimalNumber  \
# 1121  0025_01  0025              2.0  AVINOVA+COCCIAID  21.0            1
# 1130  0019_04  0019              4.0     Chllgd+Untrtd  21.0            4
# 1131  0013_02  0013              3.0          COCCIAID  14.0            2
# 1132  0023_04  0023              3.0          COCCIAID  21.0            4
# 1137  0015_03  0015              2.0  AVINOVA+COCCIAID  14.0            3
# ...       ...   ...              ...               ...   ...          ...
# 1276  0014_05  0014              7.0            PHYLOX  14.0            5
# 1277  0016_03  0016              8.0         SALINOMIX  14.0            3
# 1282  0013_05  0013              3.0          COCCIAID  14.0            5
# 1283  0016_05  0016              8.0         SALINOMIX  14.0            5
# 1286  0011_04  0011              6.0           MONECYL  14.0            4
#
#      AnimalType Project Client  House   Pen     RunID     PlateCode  \
# ...

# %% [markdown]
# ## CERDOS

# %%
experiment = "E341"

# %%
key = f"s3://siwaexperiments/{experiment}/raw.xlsx"
print(key)
# Out:
# s3://siwaexperiments/E341/raw.xlsx

# %%
df = wr.s3.read_excel(path=key, sheet_name="R")

# %%
df.head()
# Out:
#    Obs  Rep  Pen  Trt Protein       Zinc Sex     P0Date  P0Count      P0Wt  \
# 0    1    1    2    5    High         No   M 2021-08-20       19  5.921053
# 1    2    1    3    2     Low  Inorganic   M 2021-08-20       19  5.894737
# 2    3    1    4    6     Low         No   M 2021-08-20       19  5.842105
# 3    4    1    5    4     Low     Prokel   M 2021-08-20       19  5.894737
# 4    5    1    6    1    High  Inorganic   M 2021-08-20       19  6.000000
#
#    ... Phase3ADG  Phase3ADFI  Phase3FCR  Phase3Days  StoFADG  StoFADFI  \
# 0  ...       NaN         NaN        NaN      -44456      NaN       NaN
# 1  ...       NaN         NaN        NaN      -44456      NaN       NaN
# 2  ...       NaN         NaN        NaN      -44456      NaN       NaN
# 3  ...       NaN         NaN        NaN      -44456      NaN       NaN
# 4  ...       NaN         NaN        NaN      -44456      NaN       NaN
#
#    StoFFCR  TotalDays  MortCount  Mortality
# ...

# %%
key_check = "E341/performance/count_period.csv"

# %%
df = utils.read_csv_s3(key_check, bucket="siwaexperiments")

# %%
df
# Out:
#      Pen  AnimalID  House  count  period
# 0      2       NaN      1   19.0       0
# 1      2       NaN      1   18.0       1
# 2      2       NaN      1   18.0       2
# 3      2       NaN      1    0.0       3
# 4      2       NaN      1    0.0       4
# ..   ...       ...    ...    ...     ...
# 295   66       NaN      1   19.0       0
# 296   66       NaN      1   19.0       1
# 297   66       NaN      1   19.0       2
# 298   66       NaN      1    0.0       3
# 299   66       NaN      1    0.0       4
#
# [300 rows x 5 columns]

# %%
key_check = "E341/performance/treatments.csv"
df = utils.read_csv_s3(key_check, bucket="siwaexperiments")
df.head()
# Out:
#    main_id  Pen  Trt Sex
# 0        0    2    5   M
# 1        1    3    2   M
# 2        2    4    6   M
# 3        3    5    4   M
# 4        4    6    1   M

# %%
key_check = "E341/results.csv"
df = utils.read_csv_s3(key_check, bucket="siwaexperiments")
df.head()
# Out:
#                          Element  Category     Value  Treatment  Phase
# 0                    Moisture, %  Expected    10.105          1      1
# 1  Metabolizable Energy, kcal/kg  Expected  3430.000          1      1
# 2            Net Energy, kcal/kg  Expected  2573.098          1      1
# 3               Crude Protein, %  Expected    21.888          1      1
# 4              Ether extract , %  Expected     5.078          1      1

# %% [markdown]
# # POLLOS

# %% [markdown]
# ## aclarar p2d

# %%
experiment = "E335"

# %%
key = f"s3://siwaexperiments/{experiment}/raw.xlsx"
print(key)
# Out:
# s3://siwaexperiments/E335/raw.xlsx

# %%
df = wr.s3.read_excel(path=key, sheet_name="Data to stat")

# %%
df.head()
# Out:
#    House Line  Pen  Trts  Block           Trt  #Ini PreSt count  \
# 0      1    A    1     5      1     5Ca1.48α0                40
# 1      1    A    2     7      1        7Ca2α0                40
# 2      1    A    3    12      1  12Ca0.55α5k7                40
# 3      1    A    4    11      1  11Ca0.55α0k7                40
# 4      1    A    5     9      1   9Ca0.55α2.5                40
#
#    #Fn PreSt count  #Ini St count  #Fn St count  ...  Mortality 22-33d (%)  \
# 0               40             30            30  ...                   0.0
# 1               40             30            30  ...                   0.0
# 2               40             30            30  ...                   0.0
# 3               40             30            30  ...                   0.0
# 4               40             30            30  ...                   0.0
#
#    Culling 22-33d (%)  FI 0-33d (g)  WC 0-33d (g)  BWG 0-33d (g)   \
# ...

# %%
[i for i in df.columns if "#" in i]
# Out:
# ['#Ini PreSt count',
#  '#Fn PreSt count',
#  '#Ini St count',
#  '#Fn St count',
#  '#Ini Fn count',
#  '#Fn Fn count']

# %%
df[['#Ini PreSt count',
 '#Fn PreSt count',
 '#Ini St count',
 '#Fn St count',
 '#Ini Fn count',
 '#Fn Fn count']]
# Out:
#      #Ini PreSt count  #Fn PreSt count  #Ini St count  #Fn St count  \
# 0                  40               40             30            30
# 1                  40               40             30            30
# 2                  40               40             30            30
# 3                  40               40             30            30
# 4                  40               40             30            30
# ..                ...              ...            ...           ...
# 155                40               40             30            30
# 156                40               39             30            30
# 157                40               39             30            30
# 158                40               40             30            30
# 159                40               40             30            29
#
#      #Ini Fn count  #Fn Fn count
# 0               25            25
# 1               25            24
# 2               25            25
# ...

# %%
key_check = "E335/performance/count.csv"
df = utils.read_csv_s3(key_check, bucket="siwaexperiments")
df.head()
# Out:
#    House  Pen  Treatment AnimalID  num_inicial  num_final   days
# 0      1    1          5  0074_01           40         40   0-10
# 1      1    1          5  0074_01           30         30  11-21
# 2      1    1          5  0074_01           25         25  22-42
# 3      1    2          7      NaN           40         40   0-10
# 4      1    2          7      NaN           30         30  11-21

# %% [raw]
# phase2days = {
#     "PreSt":"0-10d",
#     "St":"11-21d",
#     "Fn":"22-42d"
# }

# %%
key_check = "E335/treatments.csv" # porqué no está dentro de performance?? 
df = utils.read_csv_s3(key_check, bucket="siwaexperiments")
df.head()
# Out:
#    % Ca Total  %Ca Analy.  Alpha D3  (ug/kg)  MK7 (mg/Ton)  (nPP)  \
# 0        0.67        0.55                0.0             0   0.48
# 1        0.67        0.55                5.0             0   0.48
# 2        1.02        0.90                0.0             0   0.48
# 3        1.02        0.90                5.0             0   0.48
# 4        1.60        1.48                0.0             0   0.48
#
#    Axtra phy (FTU/Kg)  Treatment  days
# 0                1200          1  0-10
# 1                1200          2  0-10
# 2                1200          3  0-10
# 3                1200          4  0-10
# 4                1200          5  0-10
